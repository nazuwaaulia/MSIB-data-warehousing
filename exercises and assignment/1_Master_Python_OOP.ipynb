# %% [markdown]
# # Python OOP
#
# **Covered Topics**
# - OOP Fundamentals
# - Concepts of OOP
#   - Inheritances
#   - Polymorphism
#   - Abstraction
#   - Encapsulation

# %% [markdown]
# ## OOP Fundamentals

# %% [markdown]
# ### OOP Structure
#
# <img src="https://docs.google.com/uc?export=download&id=1QL7ztwAFfu6OyNJl6KCuxsEErGVa98AR">

# %% [markdown]
# #### Class dan Object
#
# Untuk membuat sebuah kelas pada Bahasa Python dimulai dengan menggunakan kata kunci class dan dikuti dengan titik dua (:).
# Aturan penulisan:
#
# ```
# class <nama_kelas>:
# ```

# %%
class Handphone():
  pass

# %% [markdown]
# Seperti definisinya, class diatas akan menjadi *blueprint* dari objek/instance yang akan masukkan pada tahap selanjutnya. Lalu kita inisiasikan objek dari class yang telah kita buat.

# %%
hp_bambang = Handphone()
hp_caca = Handphone()

print(hp_bambang)
print(hp_caca)
# Out:
# <__main__.Handphone object at 0x7bd9a4e28c10>
# <__main__.Handphone object at 0x7bd9a4e28160>

# %% [markdown]
# Kode diatas artinya objek hp_bambang dan hp_caca memakai class handphone sebagai *blueprint* untuk objek tersebut.
#
# Artinya semua variabel, atau metode nantinya akan mengikuti class handphone. Sekarang kita akan masukan atribut/variabel dalam objek yang kita buat. kita akan masukkan jenis dan warna dari objek tersebut.

# %%
hp_bambang.merk = ['samsung','oppo']
hp_bambang.warna = 'biru telur asin'

# %%
hp_bambang.merk
# Out:
# ['samsung', 'oppo']

# %%
hp_bambang.warna
# Out:
# 'biru telur asin'

# %%
hp_bambang.merk = "oddo"
hp_bambang.warna = 'hijau telur asin'

hp_caca.merk = "siomay"
hp_caca.warna = 'hitam'

# %% [markdown]
# Jika kita menggunakan metode print() untuk melihat atribut dan objek yang telah kita buat maka kita akan mendapatkan

# %%
print(hp_bambang)
print(hp_bambang.warna)
print(hp_bambang.__dict__)
# Out:
# <__main__.Handphone object at 0x7bd9a4e28c10>
# hijau telur asin
# {'merk': 'oddo', 'warna': 'hijau telur asin'}

# %% [markdown]
# - Pada hasil pertama kita diperlihatkan bahwa hp_bambang merupakan sebuah objek.
#
# - Pada hasil kedua kita diperlihatkan bahwa atribut warna pada objek hp_bambang bernilai “hijau telur asin”.
#
# - Pada hasil terakhir kita ingin melihat atribut apa saja yang dimiliki oleh objek tersebut.

# %%
print(hp_caca)
print(hp_caca.merk)
print(hp_caca.__dict__)
# Out:
# <__main__.Handphone object at 0x7bd9a4e28160>
# siomay
# {'merk': 'siomay', 'warna': 'hitam'}

# %% [markdown]
# ### Methods
#
# Sebuah class memliki metode didalamnya yang dapat kita variasikan fungsinya tidak seperti metode init. Kalau kita menggunakan pemisalan sederhana, Jika objek yang kita maksudkan adalah kalkulator maka yang termasuk ke dalam metode yang dimaksud adalah operasi tambah, kurang, bagi, dan kali.
#
# Sekarang kita akan mencoba membuat metode pada class handphone sebelumnya.

# %%
class Handphone():
  pass

  def ringing(self):
    print("kring kring kring")

  def call(self, orang):
      print(f"memanggil {orang}")
      # print("memanggil "+orang)

# %% [markdown]
# method dari object, perlu ditambahkan parameter self

# %%
hp_bambang = Handphone()

hp_bambang.ringing()
# Out:
# kring kring kring

# %%
class Handphone():
  pass

  def ringing(self):
    print("kring kring kring")

  def call(self, orang):
      print(f"memanggil {orang}")
      # print("memanggil "+orang)

  def ringing2 ():
    print('brem brem')

# %%
Handphone.ringing2()
# Out:
# brem brem

# %% [markdown]
# Metode ringing adalah contoh metode yang tanpa argumen, sehingga saat melakukan pemanggilan kita tidak perlu mengisikan argumen ke dalam kurung, walaupun terdapat parameter self.
#
# Selain metode tersebut, ada juga metode dengan argumen yang akan kita contohkan dengan membuat sebuah fungsi call.

# %%
hp_bambang = Handphone()

hp_bambang.call("joko")
# Out:
# memanggil joko

# %% [markdown]
# Walaupun method call memiliki parameter self, namun tidak perlu didefinisikan ketika memanggil, cukup memasukkan parameter selain self

# %% [markdown]
# **\_\_Init\_\_ method**
#
# Metode \_\_Init\_\_ digunakan sebagai inisiasi class yang kita jalankan jadi saat kita memanggil class tersebut sebagai sebuah objek maka metode ini akan dijalankan terlebih dahulu.

# %%
class Handphone_1():
  def __init__(self):
    self.merk = 'apapun'
    self.warna = 'bebas'
    print('memanggil class Handphone')

# %%
hp_fauzan = Handphone_1()
# Out:
# memanggil class Handphone

# %%
hp_fauzan.merk
# Out:
# 'apapun'

# %%
hp_fauzan.warna
# Out:
# 'bebas'

# %%
class Handphone_3():
  def __init__(self,merk,warna,pemilik):
    self.merk = merk
    self.warna = warna
    self.pemilik = pemilik
    print('memanggil class Handphone')

# %%
hp_fauzan = Handphone_3('apel','silver titanium','fauzan')
# Out:
# memanggil class Handphone

# %%
hp_fauzan.__dict__
# Out:
# {'merk': 'apel', 'warna': 'silver titanium', 'pemilik': 'fauzan'}

# %%
print(hp_fauzan.merk)
print(hp_fauzan.warna)
print(hp_fauzan.pemilik)
# Out:
# apel
# silver titanium
# fauzan

# %%
hp_kevin = Handphone_3('samsung','violet','kevin')
# Out:
# memanggil class Handphone

# %%
print(hp_kevin.merk)
print(hp_kevin.warna)
print(hp_kevin.pemilik)
# Out:
# samsung
# violet
# kevin

# %%
class Handphone():
  def __init__(self):
    print("ini hp saya")

  def ringing(self):
    print("kring kring kring")

# %%
hp_bambang = Handphone()
# Out:
# ini hp saya

# %% [markdown]
# Seperti yang terlihat, saat kita menginisiasi pembuatan objek hp_bambang maka dengan otomatis print(“ini hp saya”) terjalankan.
#
# Jadi apa gunanya hal ini?
# dengan melakukan ini maka kita bisa lebih menyederhanakan kode yang kita tulis sehingga lebih mudah dibaca.
#
# Kita akan coba masukkan atribut merk dan warna pada fungsi init tersebut.

# %%
class Handphone:

    def __init__(self, merk, warna):
        self.merk = merk
        self.warna = warna
        print('menciptakan object Handphone')

# %%
hp_bambang = Handphone('oppo','hijau telur asin')
# Out:
# menciptakan object Handphone

# %%
print(hp_bambang)
# Out:
# <__main__.Handphone object at 0x7bd9a4e2ae90>

# %%
print(hp_bambang.warna)
# Out:
# hijau telur asin

# %%
print(hp_bambang.__dict__)
# Out:
# {'merk': 'oppo', 'warna': 'hijau telur asin'}

# %%
class Handphone:

    def __init__(self, merk, warna):
        self.merk = merk
        self.warna = warna

# %%
hp_bambang = Handphone("oddo", 'hijau telur asin')
print(hp_bambang)
print(hp_bambang.warna)
print(hp_bambang.__dict__)
# Out:
# <__main__.Handphone object at 0x7bd9947c6c50>
# hijau telur asin
# {'merk': 'oddo', 'warna': 'hijau telur asin'}

# %%
hp_caca = Handphone("siomay", 'hitam')
print(hp_caca)
print(hp_caca.warna)
print(hp_caca.__dict__)
# Out:
# <__main__.Handphone object at 0x7bd9947c7b50>
# hitam
# {'merk': 'siomay', 'warna': 'hitam'}

# %%
class Handphone():
  pass


hp_bambang = Handphone()
hp_bambang.merk = "oddo"
hp_bambang.warna = 'hijau telur asin'
print(hp_bambang)
print(hp_bambang.warna)
print(hp_bambang.__dict__)

hp_caca = Handphone()
hp_caca.merk = "siomay"
hp_caca.warna = 'hitam'
print(hp_caca)
print(hp_caca.warna)
print(hp_caca.__dict__)
# Out:
# <__main__.Handphone object at 0x7bd9947c7b80>
# hijau telur asin
# {'merk': 'oddo', 'warna': 'hijau telur asin'}
# <__main__.Handphone object at 0x7bd9947c4850>
# hitam
# {'merk': 'siomay', 'warna': 'hitam'}

# %% [markdown]
# Kesederhaan ini akan lebih terlihat lagi jika apa yang kita lakukan menjadi lebih rumit sehingga membutuhkan banyak sekali atribut maka kita hanya membutuhkan satu baris saja untuk menginisiasi sebuah objek.

# %% [markdown]
# Pada dasarnya method init sama seperti method lain, namun method ini akan selalu dijalankan ketika object pertama dipanggil dan method ini akan dijalankan pertama kali

# %% [markdown]
# ### Attribute Kelas & Attribute Objek
#
# Atribut yang kita buat sebelumnya adalah atribut objek, apa maksudnya? Maksudnya adalah atribut tersebut hanya menjadi miliki objek yang didefinisikan.
#
# Misal untuk hp_bambang merknya adalah oddo sedangkan untuk hp_caca merknya adalah siomay.
#
# Atribut kelas adalah atribut yang menjadi milik si class tersebut artinya nilainya akan sama untuk semua metode di dalam class tersebut.

# %%
class Handphone:
    entitas = 'android'

    def __init__(self, merk, warna):
        self.merk = merk
        self.warna = warna

# %%
hp_bambang = Handphone("oddo", 'hijau telur asin')
print(hp_bambang)
print(hp_bambang.warna)
print(hp_bambang.__dict__)
# Out:
# <__main__.Handphone object at 0x7bd9947c6140>
# hijau telur asin
# {'merk': 'oddo', 'warna': 'hijau telur asin'}

# %%
hp_caca = Handphone("siomay", 'hitam')
print(hp_caca)
print(hp_caca.warna)
print(hp_caca.__dict__)
# Out:
# <__main__.Handphone object at 0x7bd9947c4280>
# hitam
# {'merk': 'siomay', 'warna': 'hitam'}

# %%
print(hp_bambang.entitas)
print(hp_caca.entitas)
# Out:
# android
# android

# %%
hp_bambang.entitas = 'apel'

# %%
print(hp_bambang.entitas)
print(hp_caca.entitas)
# Out:
# apel
# android

# %%
Handphone.entitas = 'apel'

# %%
print(hp_bambang.entitas)
print(hp_caca.entitas)
# Out:
# apel
# apel

# %%
class Handphone:
    tipe = 'smartphone'

    def __init__(self, merk, warna):
        self.merk = merk
        self.warna = warna
        print('menciptakan object Handphone')

# %%
hp_fauzan = Handphone('nokia','hitam')
# Out:
# menciptakan object Handphone

# %%
hp_fauzan.tipe = "featurephone"

# %%
hp_fauzan.tipe
# Out:
# 'featurephone'

# %% [markdown]
# Sampai sini kalian sudah bisa mengenal OOP dan memuat class sederhana. dengan memanfaatkan atribut/variabel dan metode/fungsi yang sesuai.

# %% [markdown]
# ## Concepts of OOP
#
# <img src="https://docs.google.com/uc?export=download&id=1C7mSNggBhMy5jrBxIMllsw4r9gnuPFmE">

# %% [markdown]
# ### Inheritance
#
# Inheritance adalah sifat penurunan, yaitu menurunkan sifat yang dimiliki kelas utama (parent) class kepada kelas yang diturunkan (child class).
#
# ```
# NEW Class Functionality = OLD Class Functionality + EXTRA
# ```
#
#
#
# <img src="https://docs.google.com/uc?export=download&id=13CtXFytH3uAxq28QHha0aDcpQVenA91H">

# %%
class Warga():

    def __init__(self, NIK):
        self.nik = NIK
        self.memilih = True

class Satpam(Warga):
    pass

class Petugas(Warga):
    pass

# %%
muklish = Satpam('12345')
muklish

# %%
muklish.__dict__
# Out:
# {'nik': '12345', 'memilih': True}

# %%
class Warga():

    def __init__(self, NIK: str):
        self.nik = NIK
        self.memilih = False

class Satpam(Warga):
    pass

class Petugas(Warga):
    pass

# %%
muklish = Satpam("123454321")
print(muklish.nik)
# Out:
# 123454321

# %%
class Warga():
    rekap_pilihan = []

    def __init__(self, NIK: str):
        self.nik = NIK
        self.memilih = False

    def nyoblos(self, pilihan: str):
        if self.memilih == False:
          self.pilihan = pilihan
          self.memilih = True
          Warga.rekap_pilihan.append(pilihan)
          print(f"{self.nik} memilih {pilihan}")
        else:
          print(f"{self.nik} sudah memilih, tidak dapat memilih lagi")

class Satpam(Warga):
    pass

class Petugas(Warga):
    pass

# %%
muklish = Satpam("123454321")
print(muklish.nik)
muklish.nyoblos("aldi taher")

ucup = Petugas("654321")
print(ucup.nik)
ucup.nyoblos("aldi taher")
# Out:
# 123454321
# 123454321 memilih aldi taher
# 654321
# 654321 memilih aldi taher

# %%
class Satpam(Warga):
    def __init__(self, NIK, id_satpam):
        # Call the parent constructor using Classname.__init__()
        Warga.__init__(self, NIK) # <===== self is Satpam but also Warga
        # Add more constructor
        self.id_satpam = id_satpam

class Petugas(Warga):
    pass

# %%
muklish = Satpam("123454321", "satpam123")
print(muklish.nik)
print(muklish.id_satpam)
# Out:
# 123454321
# satpam123

# %%
class Satpam(Warga):
    def __init__(self, NIK, id_satpam):
        # Call the parent constructor using Classname.__init__()
        Warga.__init__(self, NIK) # <===== self is Satpam but also Warga
        # Add more constructor
        self.id_satpam = id_satpam

    def jaga_tpu(self, tempat: str):
        print(f"{self.id_satpam} jaga di {tempat}")

class Petugas(Warga):
    pass

# %%
muklish = Satpam("123454321", "satpam123")
muklish.jaga_tpu("sukamaju")
muklish.nyoblos("aldi taher")
# Out:
# satpam123 jaga di sukamaju
# 123454321 memilih aldi taher

# %%
muklish.nyoblos('giring nidji')
# Out:
# 123454321 sudah memilih, tidak dapat memilih lagi

# %%
class Petugas(Warga):
    def __init__(self, NIK, id_petugas):
        # Call the parent constructor using Classname.__init__()
        Warga.__init__(self, NIK) # <===== self is Petugas but also Warga

        # Add more constructor
        self.id_petugas = id_petugas

    def ngitung_suara(self):
        self.rekap_suara = {}
        print(Warga.rekap_pilihan)

        for suara in Warga.rekap_pilihan:
            if suara in self.rekap_suara:
                self.rekap_suara[suara] += 1
            else:
                self.rekap_suara[suara] = 1

        return self.id_petugas, self.rekap_suara

# %%
nana = Warga("1234")
nana.nyoblos("Nurhadi")

bambang = Satpam("13124", "satpam123")
bambang.nyoblos("aldi taher")
# Out:
# 1234 memilih megawati
# 13124 memilih aldi taher

# %%
jajang = Petugas("123454321", "petugas_tpu_123")

id_petugas, rekap_suara = jajang.ngitung_suara()
print(f"hasil rekap dari petugas {id_petugas} adalah {rekap_suara}")
# Out:
# ['aldi taher', 'aldi taher', 'aldi taher', 'megawati', 'aldi taher']
# hasil rekap dari petugas petugas_tpu_123 adalah {'aldi taher': 4, 'megawati': 1}

# %% [markdown]
# ### Polymorphism
#
# In simple way, polymorphism means the same function name being used for different use case
#
#
#
# ```
# class MyParent:
#    def talk(self):
#        print(“saya parent”)
#
# class MyChild(MyParent):
#    def talk(self):
#        print(“saya child”)
# ```

# %%
class Warga():
    def __init__(self, NIK: str):
        self.nik = NIK

    def nyoblos(self, pilihan: str):
        self.pilihan = pilihan
        print(f"{self.nik} memilih {pilihan}")

class Tni(Warga):
    def __init__(self, NIK, id_tni):
        # Call the parent constructor using Classname.__init__()
        super().__init__(NIK) # <===== self is Satpam but also Warga

        # Add more constructor
        self.id_tni = id_tni

    def nyoblos(self, pilihan: str):
        print(f"{self.nik} tidak boleh memilih karena terdaftar dalam anggota TNI dengan nomor id {self.id_tni}")

# %%
lambo = Tni("123r4123", "tni_123")
lambo.nyoblos("Nurhadi")
# Out:
# 123r4123 tidak boleh memilih karena terdaftar dalam anggota TNI dengan nomor id tni_123

# %% [markdown]
# ### Abstraction
#
# It allows you to create a set of methods that must be created within any child classes built from the abstract class.

# %%
from abc import ABC, abstractmethod

class Warga(ABC):
    def __init__(self, NIK: str):
        self.nik = NIK

    @abstractmethod
    def nyoblos(self):
        pass

class Tni(Warga):
    def __init__(self, NIK, id_tni):
        # Call the parent constructor using Classname.__init__()
        super().__init__(NIK) # <===== self is Satpam but also Warga

        # Add more constructor
        self.id_tni = id_tni

    def nyoblos(self, pilihan: str):
        print(f"{self.nik} tidak boleh memilih karena terdaftar dalam anggota TNI dengan nomor id {self.id_tni}")

class Satpam(Warga):
    def __init__(self, NIK, id_satpam):
        # Call the parent constructor using Classname.__init__()
        Warga.__init__(self, NIK) # <===== self is Satpam but also Warga
        # Add more constructor
        self.id_satpam = id_satpam

    def nyoblos(self, pilihan: str):
        self.pilihan = pilihan
        print(f"{self.nik} memilih {pilihan}")

# %%
lambo = Tni("123r4123", "tni_123")
lambo.nyoblos("Nurhadi")

bambang = Satpam("13124", "satpam123")
bambang.nyoblos("aldi taher")
# Out:
# 123r4123 tidak boleh memilih karena terdaftar dalam anggota TNI dengan nomor id tni_123
# 13124 memilih aldi taher

# %%
class Orang_gila(Warga):
    def __init__(self, NIK):
        # Call the parent constructor using Classname.__init__()
        Warga.__init__(self, NIK) # <===== self is Satpam but also Warga
        # Add more constructor
        self.id_satpam = id_satpam

# %%
ucok = Orang_gila("1412341")
ucok.nyoblos("giring")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-ffb54e6aa25c> in <cell line: 1>()
# ----> 1 ucok = Orang_gila("1412341")
#       2 ucok.nyoblos("giring")
#
# <ipython-input-77-f39e4157fe67> in __init__(self, NIK)
#       2     def __init__(self, NIK):
#       3         # Call the parent constructor using Classname.__init__()
# ----> 4         Warga.__init__(self, NIK) # <===== self is Satpam but also Warga
#       5         # Add more constructor
#       6         self.id_satpam = id_satpam
#
# TypeError: Warga.__init__() missing 1 required positional argument: 'nama'

# %% [markdown]
# ### Encapsulation
#
# Encapsulation is one of the fundamental principles of object-oriented programming, which refers to the ability to encapsulate or hide the methods and variables from outside of class, and only expose a public interface to interact with it.
#
# Suatu objek pada python dapat kita batasi akses yang dimiliki terhadap objek tersebut dengan menggunakan encapsulation. caranya adalah dengan menggunakan dua garis bawah (__) sebelum nama variabel.

# %%
class Warga():
    def __init__(self, NIK: str, nama: str):
        self.nik = NIK # public attr
        self.__nama = nama # private attr

mukhlis = Warga("123", "mukhlis")
print(mukhlis.__nama)
# print(mukhlis.__dict__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-f27110fee6d5> in <cell line: 7>()
#       5
#       6 mukhlis = Warga("123", "mukhlis")
# ----> 7 print(mukhlis.__nama)
#       8 # print(mukhlis.__dict__)
#
# AttributeError: 'Warga' object has no attribute '__nama'

# %%
class Warga():
    def __init__(self, NIK: str, nama: str):
        self.nik = NIK # public attr
        self.__nama = nama # private attr

    # getter method
    def get_nama(self):
        print("mengambil var nama")
        return self.__nama

# %%
mukhlis = Warga("123", "mukhlis")
print(mukhlis.get_nama())
# Out:
# mengambil var nama
# mukhlis

# %%
class Warga():
    def __init__(self, NIK: str, nama: str):
        self.__nik = NIK # public attr
        self.nama = nama # private attr

    # getter method
    def get_nik(self):
        print("mengambil var nik")
        return self.__nik

    # setter method
    def set_nik(self, nik):
        # print("mengubah nama dari {self.__nama} menjadi {nama}")
        if len(nik) != 10:
            print("nik harus 10")
        else:
            self.__nik = nik

# %%
mukhlis = Warga("123", "mukhlis")
# print(mukhlis.nik)
nama_mukhlis = mukhlis.get_nik()
print(nama_mukhlis)
# Out:
# mengambil var nik
# 123

# %%
mukhlis.__nik = '0123456789'

# %%
nama_mukhlis = mukhlis.get_nik()
print(nama_mukhlis)
# Out:
# mengambil var nik
# 123

# %%
mukhlis.set_nik("0123456789")
nama_mukhlis = mukhlis.get_nik()
print(nama_mukhlis)
# Out:
# mengambil var nik
# 0123456789

# %%
class Warga():
    def __init__(self, NIK: str, nama: str):
        self.__nik = NIK # public attr
        self.nama = nama # private attr

    # property get
    @property
    def nik(self):
        return self.__nik

# %%
mukhlis = Warga("123", "mukhlis")
nik_mukhlis = mukhlis.nik
print(nik_mukhlis)
# Out:
# 123

# %%
class Warga():
    def __init__(self, NIK: str, nama: str):
        self.__nik = NIK # public attr
        self.nama = nama # private attr

    # property get
    @property
    def nik(self):
        return self.__nik

    # property set
    @nik.setter
    def nik(self, nik):
        if len(nik) == 10:
            self.__nik = nik
        else:
            print("nik harus 10")

mukhlis = Warga("123", "mukhlis")
nik_mukhlis = mukhlis.nik
print(nik_mukhlis)

mukhlis.nik = "0123456789123"
nik_mukhlis = mukhlis.nik
print(nik_mukhlis)

mukhlis.__nik = "nama_baru"
print(mukhlis.__nik)
# Out:
# 123
# nik harus 10
# 123
# nama_baru

# %%
class Dog:
     def __init__(self, name):

          self.name = name
     def speak(self):
          return "Woof!"

fido = Dog("Fido")

print(fido.speak())
# Out:
# Woof!

# %%
class Animal:
   def speak(self):
       return "Some sound"

class Dog(Animal):
   def speak(self):
       return "Woof!"

animal = Animal()
dog = Dog()

# %%
class Animal:
   def __init__(self, name):
       self.name = name
       self.legs = 4

class Dog(Animal):
   pass

# %%
class Parent1:
    def method(self):
        print("Method from Parent1")

class Parent2:
    def method(self):
        print("Method from Parent2")

class Child(Parent1, Parent2):
    pass

# Membuat objek dari kelas Child
child = Child()

# Memanggil metode method()
child.method()
# Out:
# Method from Parent1

# %%
class Parent2:
    def method(self):
        print("Method dari Parent2")

class Parent1:
    def method(self):
        print("Method dari Parent1")

class Child(Parent2, Parent1):  # Parent2 ditulis sebelum Parent1
    pass

# Membuat objek Child
child_obj = Child()

# Memanggil metode method dari objek Child
child_obj.method()
# Out:
# Method dari Parent2

# %%
class Animal:
    def speak(self):
        print("Some sound")

class Mammal:
    def speak(self):
        print("Mammal sound")

class Dog(Animal, Mammal):
    pass

dog = Dog()
dog.speak # Output: "Mammal sound"
# Out:
# <bound method Animal.speak of <__main__.Dog object at 0x7856213e60b0>>

# %%
class A:
    def greet(self):
        print("Hello from class A")

class B:
    def greet(self):
        print("Hello from class B")

class C(A, B):
    def greet(self):
        print("Hello from class C")

c = C()
c.greet()  # Output: Hello from class C
# Out:
# Hello from class C
