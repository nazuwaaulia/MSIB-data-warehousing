# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_csv('HR_comma_sep.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %% [markdown]
# ##Sorting-Mengurutkan Data

# %%
df.sort_values('satisfaction_level').head()

# %%
df.sort_values(['number_project','last_evaluation']).head(50)

# %%
df.sort_values(['last_evaluation','number_project']).head(50)

# %%
df.sort_values(['number_project','last_evaluation'],ascending=False).head(50)

# %%
## Number project -> Descending
## Last Evaluation -> Ascending

df.sort_values(['number_project','last_evaluation'],ascending=[False,True]).head(5)

# %%
## Number project -> Descending
## Last Evaluation -> Ascending

df.sort_values(['number_project','last_evaluation'],ascending=[True,False]).head(5)

# %% [markdown]
# ## Drop Baris / Kolom - Menghilangkan Beberapa Data

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
df.drop(0).head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
# 5                   3              0     1                      0  sales
#
#    salary
# 1  medium
# 2  medium
# 3     low
# 4     low
# ...

# %%
df.drop([0,3,5]).head()

# %%
df.drop(index=3)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
# ?df.drop

# %%
df['Work_accident'].value_counts()

# %%
# Menghilangkan kolom
df.drop(['Work_accident'], axis = 1).head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  left  promotion_last_5years  sales  salary
# 0                   3     1                      0  sales     low
# 1                   6     1                      0  sales  medium
# 2                   4     1                      0  sales  medium
# 3                   5     1                      0  sales     low
# 4                   3     1                      0  sales     low

# %%
df.drop(['satisfication_level','last_evaluation','Work_accident'], axis = 1).head()

# %%
df.drop(columns=['number_project'])
# Out:
#        satisfaction_level  last_evaluation  average_montly_hours  \
# 0                    0.38             0.53                   157
# 1                    0.80             0.86                   262
# 2                    0.11             0.88                   272
# 3                    0.72             0.87                   223
# 4                    0.37             0.52                   159
# ...                   ...              ...                   ...
# 14994                0.40             0.57                   151
# 14995                0.37             0.48                   160
# 14996                0.37             0.53                   143
# 14997                0.11             0.96                   280
# 14998                0.37             0.52                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                       3              0     1                      0
# ...

# %% [markdown]
# ## Menghilangkan Duplicate Baris

# %%
df.shape

# %%
df_nonduplicated = df.drop_duplicates()

# %%
df_nonduplicated.shape

# %% [markdown]
# ## Rename Column Name

# %%
rename_dict = {
    'sales' : 'division',
    'left' : 'resign',
    'promotion_last_5years'" 'promote
}

df.renamed = df.rename(columns = rename_dict)

# %%
df.head(1)

# %%
df_renamed.head(1)

# %%
del df_renamed, df_nonduplicated

# %%
# Cara ke-2 - ubah semua nama kolom
nama_kolom = ['tingkat_kepuasan','penilaian_terakhir','jumlah_project','rata_rata_jamkerja','lama_beekrja','kecelakaan','resign','promosi_5tahun_terakhir','pekerjaan','gaji']

# %%
df.columns = []

# %%
df.columns = nama_kolom_baru

# %%
list_ukuran_sepatu = np.random.randint(low=39,high=45,size=df.shape[0])
list_ukuran_sepatu

# %%
len(list_ukuran_sepatu)

# %%
df.shape[0]

# %%
df['ukuran_sepatu'] = list_ukuran_sepatu

# %%
df['total_penilaian'] = df['penilaian_terakhir'] * df['jumlah_project']

# %%
df.head(1)

# %%
df['lama_bekerja'].value_counts()

# %%
df['lama_bekerja_group'] = np.where(df['lama_bekerja_group']>7,'lama',
                                    np.where(df['lama_bekerja_group']>4,'sedang','baru')
                                    )

# %%
df.drop('lama_bekerja',axis = 1) #gaakan kesimpan cuma nampilin aja

# %% [markdown]
# - np.where
# - .apply
# - np.cut
# - np.qcut

# %% [markdown]
# ## Data Aggregation

# %%
telco_df.shape[0]

# %%
telco_df.drop_duplicates().shape[0]

# %%
telco_df['Churn']

# %%
telco_df.groupby('gender',as_index=False)['Churn_Flag'].mean()

# %%
telco_df.groupby('SeniorCitizen',as_index=False)['Churn_Flag'].mean()

# %%
telco_df.groupby('Partner',as_index=False)['Churn_Flag'].mean()

# %%
telco_df.groupby(['SeniorCitizen','Partner'],as_index=False)['Churn_Flag'].mean()

# %% [markdown]
# ## Data Combining

# %%
import os
